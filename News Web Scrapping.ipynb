# %% [markdown]
# ## The Times of India

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
toi_url = "https://timesofindia.indiatimes.com/city/chandigarh/decline-of-hockey-due-to-poor-management/articleshow/2088679491.cms"

# %%
toi_url
# Out:
# 'https://timesofindia.indiatimes.com/city/chandigarh/decline-of-hockey-due-to-poor-management/articleshow/2088679491.cms'

# %%
urlclient = urlopen(toi_url)

# %%
toi_page = urlclient.read()

# %%
toi_html = bs(toi_page, 'html.parser')

# %%
len(toi_html.find_all("div"))
# Out:
# 341

# %%
article_body = toi_html.find_all("div", {"class" : "_s30J clearfix"})

# %%
article_body
# Out:
# [<div class="_s30J clearfix">chandigarh: former indian hockey captain pargat singh, on monday, cited non technical management at the top level of ad-ministration and improper mar-keting of players as the key rea-sons for the decline of hockey stan-dards in the country. the management at the top lev-el in the federation consists of about 90 per cent non technical persons who lack in commitment towards improving the game, par-gat singh, a padma shree awardee who captained india in 1989 for the first time, told mediapersons, here.<div class="persObserver personaliseWidgetLoader_2088679491 lJoFb xOYwg undefined" data-card="readAlso" data-contentprimestatus="non-prime" data-msid="2088679491" data-section="City" data-subsection="Chandigarh" data-template="AS" data-userprimestatus="non-prime" id="readAlso_2088679491" style="min-height:330.06px"></div>flaying the federation for not preparing an annual calender, he said that in foreign countries the domestic league was used as a training grou
# ...

# %%
len(article_body)
# Out:
# 1

# %%
article_body[0].text.strip()
# Out:
# 'chandigarh: former indian hockey captain pargat singh, on monday, cited non technical management at the top level of ad-ministration and improper mar-keting of players as the key rea-sons for the decline of hockey stan-dards in the country. the management at the top lev-el in the federation consists of about 90 per cent non technical persons who lack in commitment towards improving the game, par-gat singh, a padma shree awardee who captained india in 1989 for the first time, told mediapersons, here.flaying the federation for not preparing an annual calender, he said that in foreign countries the domestic league was used as a training ground for the national team. the indian hockey federation has been ignoring domestic leagues. national players seldom participate in such events, pargat singh said, demanding that every tournament should be adjusted ac-cording to the national and interna-tional calender. he said that all a grade tournaments should be played on astro-turfs. (pti)Explore
# ...

# %%
import requests
from bs4 import BeautifulSoup

def scrape_article(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Extract text from all paragraphs
    paragraphs = soup.find_all('div', {"class" : "_s30J clearfix"})
    article_text = '\n'.join([paragraph.get_text() for paragraph in paragraphs])

    return article_text

if __name__ == "__main__":
    url = "https://timesofindia.indiatimes.com/business/india-business/gamings-serious-business/articleshow/1013150.cms"
    article_text = scrape_article(url)

    print(article_text)
# Out:
# NEW DELHI: Gamers are fanatics, hooked virtually for life. But gaming need not be confined to only pushing buttons and keeping scores â€” it''s a serious business opportunity that needs to be tapped. When an enthralled audience is on hand, why haven''t the advertisers answered to the ''call of duty''?In FIFA 2005 (PC game), for example, the virtual teams wear real logos â€” the Arsenal team jerseys have O2 (UK mobile operator and the official sponsor of the team) on them and the Liverpool team ''wears'' Carlsberg beer.While FIFA gamers score amid virtual cheer, the real brands score subliminally."Downtown Derby is a game about a pizza delivery girl skating through city streets, collecting Pizza Hut brownie points. I love pizzas, I love games," says Gauri Chopra, a gaming devotee. She has a good appetite for pizzas and relishes the game all the more. Like an extra topping!Studies have concluded that gamers respond favourably to the ads they identify with. Advertisements add to the rea
# ...

# %%
import requests
from bs4 import BeautifulSoup

def scrape_article(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Extract text from all paragraphs
    paragraphs = soup.find_all('div', {"class" : "_s30J clearfix"})
    article_text = '\n'.join([paragraph.get_text() for paragraph in paragraphs])

    return article_text

if __name__ == "__main__":
    url = "https://timesofindia.indiatimes.com/india/national-anthem-order-challenged/articleshow/1012848.cms"
    article_text = scrape_article(url)

    print(article_text)
# Out:
# INDORE: A revision petition challenging a local court order that not standing at attention during National Anthem cannot be considered as an 'obstruction', was filed in the district and sessions court on Saturday. Challenging the order in the court of district and session judge, the counsel for the Tiranga Abhiyan, a non-governmental organisation, urged the court it will be a "serious legal mistake" to treat a person sitting during the National Anthem as not obstruction.The counsel Shailendra Dwivedi said in the prevention of insult to the National Honour Act of 1971, it has been stated any obstruction during rendition of the National Anthem is a "disrespect" to the Anthem. He said the lower court has not considered as obstruction while dismissing a petition against Railway Minister Lalu Prasad and Bihar Chief Minister Rabri Devi for being seated at the time of the playing of the National Anthem. The Act has not described the "reasons for obstructions" and in that scenario the ruling
# ...

# %%
import requests
from bs4 import BeautifulSoup

def scrape_article(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Extract text from all paragraphs
    paragraphs = soup.find_all('div', {"class" : "_s30J clearfix"})
    article_text = '\n'.join([paragraph.get_text() for paragraph in paragraphs])

    return article_text

if __name__ == "__main__":
    url = "https://timesofindia.indiatimes.com/city/mumbai/police-solve-jewellery-heist-after-a-year/articleshow/1440440.cms"
    article_text = scrape_article(url)

    print(article_text)
# Out:
# MUMBAI: A daring jewellery heist executed by a band of nine robbers at a Kandivli firm more than a year ago was solved by the police on Sunday. However, the stolen sum of Rs 25 lakh remained untraced.Senior police officers said the gang was tipped off by a disgruntled employee working with the same firm. In exchange, he was offered a sizeable share of the loot. The police are likely to apply the stringent MCOCA on the gang for operating as an organised crime syndicate.A jeweller based in an industrial estate at Kandivli's Iraniwadi had been looted on May 11, 2005. Four robbers had scaled the building at night and broken the entrance grill to enter the office on the first floor before decamping with the valuables. The loot included ornaments and gold worth Rs 23 lakh. The robbers had been armed with revolvers and choppers.For a year, the cops were unable to trace the culprits......The case was even discussed in the state assembly. Finally, they zeroed in on an employee of the firm who
# ...

# %%
import requests
from bs4 import BeautifulSoup

def scrape_article(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Extract text from all paragraphs
    paragraphs = soup.find_all('div', {"class" : "_s30J clearfix"})
    article_text = '\n'.join([paragraph.get_text() for paragraph in paragraphs])

    return article_text

if __name__ == "__main__":
    url = "https://timesofindia.indiatimes.com/city/lucknow/teachers-told-not-to-compare-students/articleshow/1872429.cms"
    article_text = scrape_article(url)

    print(article_text)
# Out:
# LUCKNOW: CBSE chairman Ashok Ganguly, on Saturday, asked teachers to keep in mind 3Cs and 3As while teaching. He was the chief guest at a function hosted by the Central Academy School.Addressing the teachers, Ganguly said that the 3Cs mean competition, compulsion and comparison, whereas 3As stand for aptitude, attitude and altitude. He said that teachers should never compare two students as it lowers the confidence of the one rated lower than the other.Further, he said, competition causes stress which is good as far as it makes children do creative things, otherwise it can make an adverse impact on the growth of the students.The CBSE chairman asked teachers to stop the practice of compelling the students scoring low in the examinations to opt for arts stream whereas encouraging those with high marks to go for science stream. He said that there could be number of reasons behind a student scoring low in a particular paper. "We should not presume that a student with low marks would not 
# ...

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
toi_url = "https://timesofindia.indiatimes.com/city/lucknow/teachers-told-not-to-compare-students/articleshow/1872429.cms"

# %%
def scrap_news(url):
    urlclient = urlopen(url)
    toi_page = urlclient.read()
    toi_html = bs(toi_page, 'html.parser')
    title = toi_html.find('h1').text.strip()
    article_body = toi_html.find_all("div", {"class" : "_s30J clearfix"})
    article_text = article_body[0].text.strip()

    return title, article_text

# %%
scrap_news(toi_url)
# Out:
# ('Teachers told not to compare students',
# ...

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging
import pymongo

# %%
def scrap_news(url):
    
    urlclient = urlopen(url)
    toi_page = urlclient.read()
    toi_html = bs(toi_page, 'html.parser')
    title = toi_html.find('h1').text.strip()
    article_body = toi_html.find_all("div", {"class" : "_s30J clearfix"})
    
    ads_elements = toi_html.find_all(class_="L65UB")  

    for ad_element in ads_elements:
        ad_element.decompose()                     # Remove the ad element and its contents from the HTML
        
    article_text = article_body[0].text.strip()
    
    client = pymongo.MongoClient("mongodb+srv://akshay20496:20496aag@cluster0.wa84jys.mongodb.net/?retryWrites=true&w=majority")
    db = client["Scrap_News"]
    collection_create = db["TOI_news_records"]
    news_data = {title : article_text}
    collection_create.insert_one(news_data)

    return title, article_text

# %%
toi_url = "https://timesofindia.indiatimes.com/world/europe/landslide-kills-at-least-seven-on-italys-ischia-island/articleshow/95811338.cms"
title, text = scrap_news(toi_url)
print(title)
print(text)
# Out:
# Landslide kills at least seven on Italy's Ischia island
# ...

# %%
def scrap_news(url):
    try:
        urlclient = urlopen(url)
        toi_page = urlclient.read()
        toi_html = bs(toi_page, 'html.parser')
        title = toi_html.find('h1').text.strip()
        article_body = toi_html.find_all("div", {"class" : "_s30J clearfix"})
        article_text = article_body[0].text.strip()
    
        client = pymongo.MongoClient("mongodb+srv://akshay20496:20496aag@cluster0.wa84jys.mongodb.net/?retryWrites=true&w=majority")
        db = client["Scrap_News"]
        collection_create = db["TOI_news_records"]
        news_data = {title : article_text}
        collection_create.insert_one(news_data)

        return title, article_text
    except Exception as e:
        logging.error

# %% [markdown]
# ## The Economic Times

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging
import pymongo

# %%
et_url = "https://economictimes.indiatimes.com/industry/auto/auto-news/kia-motors-india-announces-price-hike-after-selling-45000-units-of-seltos/articleshow/73081835.cms"

# %%
urlclient = urlopen(et_url)

# %%
et_page = urlclient.read()

# %%
et_html = bs(et_page, 'html.parser')

# %%
et_html.find('h1').text.strip()
# Out:
# 'Kia Motors India announces price hike after selling 45,000 units of Seltos'

# %%
x = et_html.find_all("div", {"data-brcount" : str(21)})

# %%
x[0].text.strip()
# Out:
# 'NEW DELHI: Indian citizenship would not be granted to any foreigner without the consent of state governments concerned after the passage of the Citizenship (Amendment) Bill, the Home Ministry said on Tuesday.Ministry spokesperson Ashok Prasad said every application for Indian citizenship will be enquired into by the deputy commissioner or district magistrate concerned, who will carry out due diligence and submit it to the state government concerned."The state government also has to conduct an enquiry through its agencies. Only then, an individual will be granted Indian nationality. Without the state government\'s recommendations, no one will be given Indian citizenship," Prasad told reporters here.The Citizenship Amendment Bill 2019, being strongly opposed by a large section of people and organisations in the Northeast, seeks to provide Indian citizenship to persecuted minorities -- Hindus, Sikhs, Jains, Buddhists and Christians -- from Bangladesh, Pakistan and Afghanistan after the
# ...

# %%
element_with_brcount = et_html.find(attrs={"data-brcount": True})

# %%
element_with_brcount.text.strip()
# Out:
# 'South Korean automaker Kia Motors hiked the price of its maiden car in India, the Seltos compact SUV, after the company had a dream run selling over 45,000 units in a little over four months.The prices of Seltos have been revised upwards by Rs 20,000 to Rs 35,000 across variants. The launch price of Rs 9.69 lakh, ex-showroom for the base variant was an introductory price limited only till 31 December 2019, said Kia Motor India, the Indian arm of Korean carmaker.Kia was not the only manufacturer to hike prices from January. Automobile manufacturers conventionally raise prices around the beginning of every new year to incentivise customers into purchasing older vehicles before the model-year changes and their value takes a hit.Maruti Suzuki, Mahindra & Mahindra (M&M), Ford India, Toyota Kirloskar Motor (TKM), Mercedes Benz and Audi India were some of the other manufacturers who hiked prices of their vehicles starting this new year, ET had reported earlier. The price hikes were to coun
# ...

# %%
client = pymongo.MongoClient("mongodb+srv://akshay20496:20496aag@cluster0.wa84jys.mongodb.net/?retryWrites=true&w=majority")

# %%
client.list_database_names()
# Out:
# ['Scrap_News', 'image_scrap', 'scrapper_eng_pwskills', 'admin', 'local']

# %%
y = client.get_database("Scrap_News")

# %%
y.list_collection_names()
# Out:
# ['TOI_news_records']

# %%
def scrap_news_1(url):
    
    urlclient = urlopen(url)
    et_page = urlclient.read()
    et_html = bs(et_page, 'html.parser')
    title = et_html.find('h1').text.strip()
    article_body = et_html.find(attrs = {"data-brcount" : True})
    article_text = article_body.text.strip()
    
    client = pymongo.MongoClient("mongodb+srv://akshay20496:20496aag@cluster0.wa84jys.mongodb.net/?retryWrites=true&w=majority")
    db1 = client.get_database("Scrap_News")
    collection_create_1 = db1["ET_news_records"]
    news_data_1 = {title : article_text}
    collection_create_1.insert_one(news_data_1)
    
    return title, article_text

# %%
et_url = "https://economictimes.indiatimes.com/news/politics-and-nation/indian-origin-scientist-ramakrishnan-honoured-with-knighthood/articleshow/11313669.cms"
Title, text = scrap_news_1(et_url)
print(Title)
print(text)
# Out:
# Indian-origin scientist Ramakrishnan honoured with knighthood
# ...

# %% [markdown]
# ## The Hindu

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging
import pymongo

# %%
hindu_url = "https://www.thehindu.com/news/international/clashes-follow-protesters-funeral-in-bahrain/article2766404.ece"

# %%
response = requests.get(hindu_url)

# %%
response
# Out:
# <Response [200]>

# %%
soup = bs(response.content, 'html.parser')

# %%
title = soup.find('h1').text.strip()

# %%
title
# Out:
# 'Clashes follow protester’s funeral in Bahrain'

# %%
article_body = soup.find_all('div', {"id" : "content-body-60477109"})

# %%
text = ''
for i in article_body[0].get_text():
    if i != '\n':
        text = text + i
    else:
        break
print(text)
# Out:
# Witnesses say riot police in Bahrain used tear gas and rubber bullets to disperse opposition supporters following a mass funeral for a 15-year-old boy activists say was killed during clashes.The opposition says Sayed Hashim Saeed died on Saturday after a tear gas canister fired at close range hit him in the chest.The Interior Ministry says that burns on the boy’s body cannot have come from a tear gas canister. They asked the public prosecutor to investigate.Police earlier tried to seal off the site of Sunday’s funeral in the south of the capital Manama, to prevent crowds from converging.Bahrain’s Shia-led opposition has been protesting for more than 10 months for more rights from the Sunni rulers of the Gulf kingdom.

# %%
div = soup.find_all("div")

# %%
len(div)
# Out:
# 137

# %%
y = soup.find_all("div", {'class' : "articlebodycontent col-xl-9 col-lg-12 col-md-12 col-sm-12 col-12"})

# %%
len(y)
# Out:
# 1

# %%
y[0].get_text()
# Out:
# 'Witnesses say riot police in Bahrain used tear gas and rubber bullets to disperse opposition supporters following a mass funeral for a 15-year-old boy activists say was killed during clashes.The opposition says Sayed Hashim Saeed died on Saturday after a tear gas canister fired at close range hit him in the chest.The Interior Ministry says that burns on the boy’s body cannot have come from a tear gas canister. They asked the public prosecutor to investigate.Police earlier tried to seal off the site of Sunday’s funeral in the south of the capital Manama, to prevent crowds from converging.Bahrain’s Shia-led opposition has been protesting for more than 10 months for more rights from the Sunni rulers of the Gulf kingdom.\nCOMMents\n SHARE\n\nCopy link\n\nEmail\n\nFacebook\n\nTwitter\n\nTelegram\n\nLinkedIn\n\nWhatsApp\n\nReddit\n\nfunction createElementScript(element, className, id = null) {\nvar el = document.createElement(element);\nel.className = className;\nif(className == "dfp-ad")
# ...

# %%
def scrap_news_2(url):
    
    response = requests.get(url)
    soup = bs(response.content, 'html.parser')
    title = soup.find('h1').text.strip()
    article_body = soup.find_all("div", {'class' : "articlebodycontent col-xl-9 col-lg-12 col-md-12 col-sm-12 col-12"})
    article_text = ''
    for i in article_body[0].get_text():
        if i != "\n":
            article_text = article_text + i
        else:
            break
    
    client = pymongo.MongoClient("mongodb+srv://akshay20496:20496aag@cluster0.wa84jys.mongodb.net/?retryWrites=true&w=majority")
    db2 = client.get_database("Scrap_News")
    collection_create_2 = db2["Hindu_news_records"]
    news_data_2 = {title : article_text}
    collection_create_2.insert_one(news_data_2)
    
    return title, article_text

# %%
hindu_url = "https://www.thehindu.com/news/international/biden-backs-ukraine-warns-against-allowing-putin-to-win/article67635165.ece"
title, text = scrap_news_2(hindu_url)
print(title)
print(text)
# Out:
# Biden backs Ukraine, warns against allowing Putin to win
# ...

# %% [markdown]
# ## Business Standard

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging
import pymongo

# %%
bs_url = "https://www.tbsnews.net/international/iran-tanker-prepares-leave-after-gibraltar-decides-free-it"

# %%
response = requests.get(bs_url)

# %%
soup = bs(response.content, 'html.parser')

# %%
title = soup.find('h1').text.strip()

# %%
print(title)
# Out:
# Iran tanker prepares to leave after Gibraltar decides to free it

# %%
x = soup.find_all('p')

# %%
len(x)
# Out:
# 18

# %%
x.pop(0)
# Out:
# <p class="mb-10">Sunday<br/></p>

# %%
x.pop(len(x) - 1)
# Out:
# <p>For advertisement- <a href="/cdn-cgi/l/email-protection#daa9bbb6bfa99aaeb8a9b4bfada9f4b4bfae"><span class="__cf_email__" data-cfemail="6714060b0214271305140902101449090213">[email protected]</span></a></p>

# %%
len(x)
# Out:
# 15

# %%
y = ''

for i in x:
    y = y + i.text.strip()
print(y)
# Out:
# SundayAn Iranian oil tanker is being reflagged and is preparing to sail to the Mediterranean, Iran's state television reported on Friday, after Gibraltar decided to free the seized ship."Based on the owner's request, the oil tanker Grace 1 will depart for the Mediterranean after being reflagged under the Iranian flag and renamed Adrian Darya after preparing for the journey," the television quoted Jalil Eslami, deputy head of Iran's Ports and Maritime Organisation, as saying.Britain's Mediterranean territory Gibraltar decided on Thursday to free the Panama-flagged tanker, but did not immediately indicate when or if the ship would set sail after the United States launched a new, last-minute legal bid to hold it."The 25-member crew will start their journey after preparations, including refueling," Eslami said.The television report did not identify the tanker's owner.The Grace 1 was seized by British Royal Marine commandos off the coast of the territory at the western mouth of the Medite
# ...

# %%
body = soup.find_all("div")

# %%
body
# Out:
# [<div id="___tbspushdiv"></div>,
#  <div id="fb-root"></div>,
#  <div class="nocontent">
#  <a class="element-invisible element-focusable" href="#main-content">Skip to main content</a>
#  </div>,
#  <div class="page off-canvas-wrapper" role="document">
#  <div class="inner-wrap off-canvas-wrapper-inner" data-off-canvas-wrapper="" id="inner-wrap">
#  <aside class="off-canvas position-left" data-off-canvas="" id="off-canvas-menu">
#  <button aria-label="Close menu" class="close-button" data-close="" type="button">
#  <span aria-hidden="true">×</span>
#  </button>
# ...

# %%
z = ''
body.pop(0)
for i in body:
    z = z + i.text.strip()
print(z)
# Out:
# An Iranian oil tanker is being reflagged and is preparing to sail to the Mediterranean, Iran's state television reported on Friday, after Gibraltar decided to free the seized ship."Based on the owner's request, the oil tanker Grace 1 will depart for the Mediterranean after being reflagged under the Iranian flag and renamed Adrian Darya after preparing for the journey," the television quoted Jalil Eslami, deputy head of Iran's Ports and Maritime Organisation, as saying.Britain's Mediterranean territory Gibraltar decided on Thursday to free the Panama-flagged tanker, but did not immediately indicate when or if the ship would set sail after the United States launched a new, last-minute legal bid to hold it."The 25-member crew will start their journey after preparations, including refueling," Eslami said.The television report did not identify the tanker's owner.The Grace 1 was seized by British Royal Marine commandos off the coast of the territory at the western mouth of the Mediterranea
# ...

# %%
def scrap_news_3(url):
        
    response = requests.get(url)
    soup = bs(response.content, 'html.parser')
    title = soup.find('h1').text.strip()
    article_body = soup.find_all("div", {"class" : "section-content clearfix margin-bottom-2"})
    article_text = ""
    for i in article_body[0].text.strip():
        if i == "\n" :
            continue
        else:
            article_text += i
    
    client = pymongo.MongoClient("mongodb+srv://akshay20496:20496aag@cluster0.wa84jys.mongodb.net/?retryWrites=true&w=majority")
    db3 = client.get_database("Scrap_News")
    collection_create_3 = db3["Business_Standard_news_records"]
    news_data_3 = {title : article_text}
    collection_create_3.insert_one(news_data_3)
    
    return title, article_text

# %%
bs_url = "https://www.tbsnews.net/international/iran-tanker-prepares-leave-after-gibraltar-decides-free-it"
title, text = scrap_news_3(bs_url)
print(title)
print(text)
# Out:
# Iran tanker prepares to leave after Gibraltar decides to free it
# ...

# %%
url = "https://www.tbsnews.net/tech/oracle-cloud-open-new-cloud-regions"

try:
    response = requests.get(url)
    response.raise_for_status()

    soup = bs(response.text, 'html.parser')

    # Find and exclude elements with specific classes or attributes associated with ads
    ads_elements = soup.find_all(class_="hide-for-print mb-20 text-center")  # Replace "ad-class" with the actual class name used for ads

    for ad_element in ads_elements:
        ad_element.decompose()  # Remove the ad element and its contents from the HTML

    # Extract text from the remaining content
    article_body = soup.find_all("div", {"class" : "section-content clearfix margin-bottom-2"})
    news_text = ""
    for i in article_body[0].text.strip():
        if i == "\n" :
            continue
        else:
            news_text += i
    print(news_text)

except requests.exceptions.RequestException as e:
    print(f"Error fetching the page: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Oracle Cloud has planned to launch 20 new Oracle Cloud regions by the end of 2020 to support its customers worldwide.This expansion will bring its total cloud regions to 36. The expansion includes regions in new countries and dual, geographically separated regions, in the US, Canada, Brazil, UK, EU, Japan, South Korea, Australia, India, UAE, Saudi Arabia, Israel, and new government regions in the UK and Israel. Additionally, Oracle is going to update its roadmap for its interconnection with Microsoft Azure.With in-country dual regions, "customers can deploy both production and disaster recovery capacity within their country or jurisdiction to meet business continuity and compliance requirements," said Oracle in a press release.It will also offer customers access to all Oracle Cloud Infrastructure services including Oracle Autonomous Database and Oracle Fusion Applications, in these regions."Enterprise customers worldwide require geographically distributed regions for true business co
# ...

# %%
def scrap_news_3(url):
        
    response = requests.get(url)
    
    soup = bs(response.content, 'html.parser')
    
    title = soup.find('h1').text.strip()
    
    ads_elements = soup.find_all(class_="hide-for-print mb-20 text-center")  

    for ad_element in ads_elements:
        ad_element.decompose()  # Remove the ad element and its contents from the HTML

    article_body = soup.find_all("div", {"class" : "section-content clearfix margin-bottom-2"})
    
    article_text = ""
    for i in article_body[0].text.strip():
        if i == "\n" :
            continue
        else:
            article_text += i
    
    client = pymongo.MongoClient("mongodb+srv://akshay20496:20496aag@cluster0.wa84jys.mongodb.net/?retryWrites=true&w=majority")
    db3 = client.get_database("Scrap_News")
    collection_create_3 = db3["Business_Standard_news_records"]
    news_data_3 = {title : article_text}
    collection_create_3.insert_one(news_data_3)
    
    return title, article_text

# %%
bs_url = "https://www.tbsnews.net/sports/messi-named-times-athlete-year-752554"
title, text = scrap_news_3(bs_url)
print(title)
print(text)
# Out:
# Messi named Time's 'Athlete of the Year'
# ...

# %% [markdown]
# ## Financial Express

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging
import pymongo

# %%
fe_url = "https://www.financialexpress.com/archive/oneplus-one-to-have-invite-model-in-india-price-under-rs-25000/1303602/"

# %%
urlclient = urlopen(fe_url)

# %%
url_page = urlclient.read()

# %%
fe_html = bs(url_page, 'html.parser')

# %%
title = fe_html.find('h1').text.strip()

# %%
print(title)
# Out:
# OnePlus One to have invite model in India, price under Rs 25,000

# %%
body = fe_html.find_all("div", {"class" : "pcl-container"})

# %%
body[0].text.strip()
# Out:
# 'OnePlus One, the phone that promises the “best performing specs in the market”, will soon start shipping to buyers in India. The company, which has signed up Vikas Agarwal as its new India GM, said in a forum post that purchase opportunity in India will be initially limited to only those with invites. The company seems to be treading cautiously and admits that they didn?t want to be too ambitious gives that this is their first experience with the Indian market. ?Invites have been immensely helpful for us thus far in our current launch countries. They allow us to control our inventory, scale our team and support services to grow along with demand and create an overall better experience for those users with the One,? said the post by Carl Pei, the director of OnePlus Global.In an email interaction with IndianExpress.com, Pei had said that the company, which has its head quarters in Shenzen, China, was ?actively seeking the right partners and processes with which to launch successfully
# ...

# %%
ads_elements = fe_html.find_all(class_="parent_also_read")  # Replace "ad-class" with the actual class name used for ads

for ad_element in ads_elements:
    ad_element.decompose()  # Remove the ad element and its contents from the HTML

# %%
text = '' 
for i in body[0].text.strip():
    if i == '?':
        continue
    else:
        text += i
print(text)
# Out:
# OnePlus One, the phone that promises the “best performing specs in the market”, will soon start shipping to buyers in India. The company, which has signed up Vikas Agarwal as its new India GM, said in a forum post that purchase opportunity in India will be initially limited to only those with invites. The company seems to be treading cautiously and admits that they didnt want to be too ambitious gives that this is their first experience with the Indian market. Invites have been immensely helpful for us thus far in our current launch countries. They allow us to control our inventory, scale our team and support services to grow along with demand and create an overall better experience for those users with the One, said the post by Carl Pei, the director of OnePlus Global.In an email interaction with IndianExpress.com, Pei had said that the company, which has its head quarters in Shenzen, China, was actively seeking the right partners and processes with which to launch successfully in t
# ...

# %%
def scrap_news_4(url):
    
    urlclient = urlopen(url)
    url_page = urlclient.read()
    fe_html = bs(url_page, 'html.parser')
    title = fe_html.find('h1').text.strip()
    article_body = fe_html.find_all("div", {"class" : "pcl-container"})
    
    ads_elements = fe_html.find_all(class_="parent_also_read")  

    for ad_element in ads_elements:
        ad_element.decompose()                     # Remove the ad element and its contents from the HTML
        
    article_text = ''
    for i in article_body[0].text.strip():
        if i == '?':
            continue
        else:
            article_text += i
    
    client = pymongo.MongoClient("mongodb+srv://akshay20496:20496aag@cluster0.wa84jys.mongodb.net/?retryWrites=true&w=majority")
    db4 = client.get_database("Scrap_News")
    collection_create_4 = db4["Financial_Express_news_records"]
    news_data_4 = {title : article_text}
    collection_create_4.insert_one(news_data_4)
    
    return title, article_text

# %%
fe_url = "https://www.financialexpress.com/archive/fitness-age-a-better-indicator-of-longevity/1299577/"
title, text = scrap_news_4(fe_url)
print(title)
print(text)
# Out:
# Fitness age a better indicator of longevity
# ...

# %% [markdown]
# ## Deccan Chronicle

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging
import pymongo

# %%
dc_url = "https://www.deccanchronicle.com/opinion/columnists/170723/aakar-patel-the-new-race-in-space-can-india-emerge-on-top-what-lie.html"

# %%
dc_url
# Out:
# 'https://www.deccanchronicle.com/opinion/columnists/170723/aakar-patel-the-new-race-in-space-can-india-emerge-on-top-what-lie.html'

# %%
response = requests.get(dc_url)

# %%
soup = bs(response.content, 'html.parser')

# %%
title = soup.find('h1').text.strip()

# %%
print(title)
# Out:
# Aakar Patel | The new race in space: Can India emerge on top? What lies next?

# %%
body = soup.find_all("div", {"class" : "details-info"})

# %%
print(body[0].text.strip())
# Out:
# In the dozen years between 1957 and 1969, the Americans and the Russians went on a series of space races. The Russians won almost everything at first. They were to first to send a satellite into orbit (Sputnik in 1957), the first to send a living thing into space, the dog Laika in the same year, the first to send a human being into orbit (Yuri Gagarin in 1961). The first person to "walk" in space, meaning exit the spacecraft while in orbit, was Aleksey Leonov in 1965. After this the United States registered its first win in 1969 when it was able to land humans on the moon. The US remains the only nation to be able to do this and it last did so in 1972. The Soviet Union tried and failed to develop a large rocket and so the space race virtually ended in the early 1970s. For 50 years, there has been no interest in moon landings with humans because the cost is very high and the American public lost interest.
# ...

# %%
paragraphs = soup.find_all('p')
merged_paragraph = ' '.join(paragraph.get_text(strip=True) for paragraph in paragraphs)

# %%
text = ''
for i in body[0].text.strip():
    if i == '\n':
        continue
    else:
        text += i
print(text)
# Out:
# In the dozen years between 1957 and 1969, the Americans and the Russians went on a series of space races. The Russians won almost everything at first. They were to first to send a satellite into orbit (Sputnik in 1957), the first to send a living thing into space, the dog Laika in the same year, the first to send a human being into orbit (Yuri Gagarin in 1961). The first person to "walk" in space, meaning exit the spacecraft while in orbit, was Aleksey Leonov in 1965. After this the United States registered its first win in 1969 when it was able to land humans on the moon. The US remains the only nation to be able to do this and it last did so in 1972. The Soviet Union tried and failed to develop a large rocket and so the space race virtually ended in the early 1970s. For 50 years, there has been no interest in moon landings with humans because the cost is very high and the American public lost interest.The Space Shuttle programme was seen as a lower-cost, reusable way for America to
# ...

# %%
def scrap_news_5(url):
    
    response = requests.get(url)
    soup = bs(response.content, 'html.parser')
    
    title = soup.find('h1').text.strip()
    
    article_body = soup.find_all("div", {"class" : "details-info"})
    
    article_text = ''
    for i in article_body[0].text.strip():
        if i == '\n':
            continue
        else:
            article_text += i
    
    client = pymongo.MongoClient("mongodb+srv://akshay20496:20496aag@cluster0.wa84jys.mongodb.net/?retryWrites=true&w=majority")
    db5 = client.get_database("Scrap_News")
    collection_create_5 = db5["Deccan_Chronicle_news_records"]
    news_data_5 = {title : article_text}
    collection_create_5.insert_one(news_data_5)
    
    return title, article_text

# %%
dc_url = "https://www.deccanchronicle.com/sports/tennis/110923/djokovic-wins-us-open-record-24th-grand-slam-singles-title.html"
title, text = scrap_news_5(dc_url)
print(title)
print(text)
# Out:
# Djokovic wins US Open, record 24th Grand Slam singles title
# Roger Federer, 20

# %%
client = pymongo.MongoClient("mongodb+srv://akshay20496:20496aag@cluster0.wa84jys.mongodb.net/?retryWrites=true&w=majority")

# %%
db1 = client.get_database("Scrap_News")

# %%
db1.list_collection_names()
# Out:
# ['Deccan_Chronicle_news_records',
#  'Hindu_news_records',
#  'Financial_Express_news_records',
#  'TOI_news_records',
#  'ET_news_records',
#  'Business_Standard_news_records']

# %%
coll_create_1 = db1.get_collection("Deccan_Chronicle_news_records")

# %%
for i in coll_create_1.find():
    print(i)
# Out:
# {'_id': ObjectId('659429a4602e420d83ff447b'), 'Aakar Patel | The new race in space: Can India emerge on top? What lies next?': 'In the dozen years between 1957 and 1969, the Americans and the Russians went on a series of space races. The Russians won almost everything at first. They were to first to send a satellite into orbit (Sputnik in 1957), the first to send a living thing into space, the dog Laika in the same year, the first to send a human being into orbit (Yuri Gagarin in 1961). The first person to "walk" in space, meaning exit the spacecraft while in orbit, was Aleksey Leonov in 1965. After this the United States registered its first win in 1969 when it was able to land humans on the moon. The US remains the only nation to be able to do this and it last did so in 1972. The Soviet Union tried and failed to develop a large rocket and so the space race virtually ended in the early 1970s. For 50 years, there has been no interest in moon landings with humans because the cost is v
# ...

# %%
data = list(coll_create_1.find())

# %%
# Convert MongoDB ObjectId to string
for record in data:
    if '_id' in record:
        record['_id'] = str(record['_id'])

# %%
import json

# %%
# Save data to JSON file
json_file_name = "Deccan_Chronicle_news_records.json"
with open(json_file_name, 'w', encoding='utf-8') as json_file:
    json.dump(data, json_file, indent=4, ensure_ascii=False)

# %%
collections = db1.list_collection_names()

# %%
print(collections)
# Out:
# ['Deccan_Chronicle_news_records', 'Hindu_news_records', 'Financial_Express_news_records', 'TOI_news_records', 'ET_news_records', 'Business_Standard_news_records']

# %%
# Iterate through each collection
for collection_name in collections:
    # Fetch data from the collection
    collection = db1[collection_name]
    data = list(collection.find())

    # Convert MongoDB ObjectId to string
    for record in data:
        if '_id' in record:
            record['_id'] = str(record['_id'])

    # Save data to JSON file
    json_file_name = f"{collection_name}.json"
    with open(json_file_name, 'w', encoding='utf-8') as json_file:
        json.dump(data, json_file, indent=4, ensure_ascii=False)
    
    print(f"Data from {collection_name} has been exported to {json_file_name}")
# Out:
# Data from Deccan_Chronicle_news_records has been exported to Deccan_Chronicle_news_records.json
# Data from Hindu_news_records has been exported to Hindu_news_records.json
# Data from Financial_Express_news_records has been exported to Financial_Express_news_records.json
# Data from TOI_news_records has been exported to TOI_news_records.json
# Data from ET_news_records has been exported to ET_news_records.json
# Data from Business_Standard_news_records has been exported to Business_Standard_news_records.json

# %%
# Close MongoDB connection
client.close()
